# %%
import pandas as pd
import numpy as np

data_climate = pd.read_csv('dataset/data_climate.csv')
data_management = pd.read_csv('dataset/data_management.csv')
data_traits = pd.read_csv('dataset/data_traits.csv')
data_trials = pd.read_csv('dataset/data_trials.csv')

# %% [markdown]
# ## Data Preprocessing

# %%
data_traits.head(3)
# Out:
#                   experiment_id management crop_type crop_season plant_family  \
# 0  Angers_brainsurlauthion_2011         M1        SC      winter       cereal
# 1  Angers_brainsurlauthion_2011         M1        SC      winter       cereal
# 2  Angers_brainsurlauthion_2011         M1        SC      winter       cereal
#
#           species     species_mix cultivar cultivar_mix  density_relative  \
# 0  wheat_aestivum  wheat_aestivum  cezanne      cezanne               1.0
# 1  wheat_aestivum  wheat_aestivum  cezanne      cezanne               1.0
# 2  wheat_aestivum  wheat_aestivum  cezanne      cezanne               1.0
#
#   density_factor sowing_date harvest_date  N_amount measurement_date  \
# 0              1  2010-10-29   2011-07-06       140       2011-03-23
# 1              1  2010-10-29   2011-07-06       140       2011-03-28
# 2              1  2010-10-29   2011-07-06       140       2011-05-12
#
#         variable     value
# 0  biomass_shoot  0.913225
# 1         height  0.324667
# 2         height  0.924000

# %%
data_traits[['measurement_date', 'harvest_date', 'sowing_date']] = data_traits[
    ['measurement_date', 'harvest_date', 'sowing_date']
].apply(lambda col: pd.to_datetime(col).dt.normalize())

# %%
data_traits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34737 entries, 0 to 34736
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   experiment_id     34737 non-null  object
#  1   management        34737 non-null  object
#  2   crop_type         34737 non-null  object
#  3   crop_season       34737 non-null  object
#  4   plant_family      34737 non-null  object
#  5   species           34737 non-null  object
#  6   species_mix       34737 non-null  object
#  7   cultivar          34737 non-null  object
#  8   cultivar_mix      34737 non-null  object
#  9   density_relative  34737 non-null  float64
#  10  density_factor    34737 non-null  object
#  11  sowing_date       34737 non-null  datetime64[ns]
#  12  harvest_date      34737 non-null  datetime64[ns]
#  13  N_amount          34737 non-null  int64
#  14  measurement_date  34737 non-null  datetime64[ns]
#  15  variable          34737 non-null  object
#  16  value             34737 non-null  float64
# dtypes: datetime64[ns](3), float64(2), int64(1), object(11)
# memory usage: 4.5+ MB

# %%
# merge values that has plant_density value before harvest and a biomass_seed(yield) value on harvest

# stable ID columns for merging (exclude crop_season, etc.)
merge_keys = [
    'experiment_id', 'management', 'crop_type', 'crop_season',
    'plant_family', 'species', 'species_mix',
    'sowing_date', 'harvest_date'
]

# Get biomass_seed at harvest
biomass_seed_df = data_traits[
    (data_traits['variable'] == 'biomass_seed') &
    (data_traits['measurement_date'] == data_traits['harvest_date'])
][merge_keys + ['value']].rename(columns={'value': 'biomass_seed'})

# Get plant_density before harvest
plant_density_df = data_traits[
    (data_traits['variable'] == 'plant_density') &
    (data_traits['measurement_date'] < data_traits['harvest_date'])
][merge_keys + ['value']].rename(columns={'value': 'plant_density'})

# Merge biomass and density on stable keys
merged_df = pd.merge(biomass_seed_df, plant_density_df, on=merge_keys, how='inner')

# Now join back excluded features from original data_traits (dropping duplicates)
extra_features = data_traits[merge_keys + ['density_relative', 'density_factor', 'N_amount', 'cultivar', 'cultivar_mix']].drop_duplicates()

merged_df = pd.merge(merged_df, extra_features, on=merge_keys, how='left')

# %%
merged_df.head(2).T
# Out:
#                                     0                    1
# experiment_id       Angers_fnams_2002    Angers_fnams_2002
# management                         M1                   M2
# crop_type                          SC                   SC
# crop_season                    spring               spring
# plant_family                   cereal               legume
# species                        barley                  pea
# species_mix                    barley                  pea
# sowing_date       2002-03-28 00:00:00  2002-03-28 00:00:00
# harvest_date      2002-07-08 00:00:00  2002-07-08 00:00:00
# biomass_seed                      3.9                  6.2
# plant_density                    87.0                 57.0
# density_relative                  1.0                  1.0
# density_factor                      1                    1
# N_amount                            0                    0
# cultivar                     scarlett              baccara
# cultivar_mix                 scarlett              baccara

# %%
intercrops = [col for col in data_traits['species_mix'].unique() if '_' in col]

merged_df = merged_df[merged_df['species_mix'].isin(intercrops)]

# %%
merged_df
# Out:
#                                 experiment_id management crop_type  \
# 2                           Angers_fnams_2002         M3        IC
# 3                           Angers_fnams_2002         M3        IC
# 8                           Angers_fnams_2003         M5        IC
# 9                           Angers_fnams_2003         M5        IC
# 10                          Angers_fnams_2003         M6        IC
# ..                                        ...        ...       ...
# 787  Sanmarcoargentano_sanmarcoargentano_2004         M3        IC
# 790                    Taastrup_taastrup_2003         M3        IC
# 791                    Taastrup_taastrup_2003         M3        IC
# 792                    Taastrup_taastrup_2003         M4        IC
# 793                    Taastrup_taastrup_2003         M4        IC
#
#     crop_season plant_family species species_mix sowing_date harvest_date  \
# 2        spring       cereal  barley  barley_pea  2002-03-28   2002-07-08
# 3        spring       legume     pea  barley_pea  2002-03-28   2002-07-08
# 8        spring       cereal  barley  barley_pea  2003-03-12   2003-07-08
# 9        spring       legume     pea  barley_pea  2003-03-12   2003-07-08
# 10       spring       cereal  barley  barley_pea  2003-03-12   2003-07-08
# ..          ...          ...     ...         ...         ...          ...
# 787      spring       legume     pea  barley_pea  2004-03-15   2004-06-25
# 790      spring       cereal  barley  barley_pea  2003-04-04   2003-07-26
# 791      spring       legume     pea  barley_pea  2003-04-04   2003-07-26
# 792      spring       cereal  barley  barley_pea  2003-04-04   2003-07-26
# 793      spring       legume     pea  barley_pea  2003-04-04   2003-07-26
#
#      biomass_seed  plant_density  density_relative density_factor  N_amount  \
# 2        1.300000      33.000000              0.33         0.33_1         0
# 3        3.400000      54.000000              1.00         0.33_1         0
# 8        1.968870     100.000000              0.50        0.5_0.5         0
# 9        4.321120      45.000000              0.50        0.5_0.5         0
# 10       4.490746     127.000000              0.50        0.5_0.5       130
# ..            ...            ...               ...            ...       ...
# 787      2.122396      91.250000              0.50        0.5_0.5         0
# 790      1.929750     115.833333              0.50        0.5_0.5         0
# 791      1.418750      38.333333              0.50        0.5_0.5         0
# 792      1.627250     122.500000              0.50          0.5_1         0
# 793      1.792250      66.666667              1.00          0.5_1         0
#
#      cultivar      cultivar_mix
# 2    scarlett  scarlett_baccara
# 3     baccara  scarlett_baccara
# 8    scarlett  scarlett_baccara
# 9     baccara  scarlett_baccara
# 10   scarlett  scarlett_baccara
# ..        ...               ...
# 787   baccara  scarlett_baccara
# 790  scarlett  scarlett_baccara
# 791   baccara  scarlett_baccara
# 792  scarlett  scarlett_baccara
# 793   baccara  scarlett_baccara
#
# [632 rows x 16 columns]

# %%
data_management.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   experiment_id           915 non-null    object
#  1   management              915 non-null    object
#  2   crop_type               915 non-null    object
#  3   crop_season             915 non-null    object
#  4   species                 915 non-null    object
#  5   species_mix             915 non-null    object
#  6   cultivar                915 non-null    object
#  7   cultivar_mix            915 non-null    object
#  8   density_level           915 non-null    float64
#  9   density_relative        915 non-null    float64
#  10  density_factor          915 non-null    object
#  11  interrow                858 non-null    float64
#  12  mixing_pattern          616 non-null    object
#  13  code_row                118 non-null    object
#  14  mixture_design          616 non-null    object
#  15  sowing_date             915 non-null    object
#  16  harvest_date            915 non-null    object
#  17  N_amount                915 non-null    int64
#  18  N_fertilisation_number  460 non-null    float64
#  19  N_fertilisation_dose_1  400 non-null    float64
#  20  N_fertilisation_dose_2  92 non-null     float64
#  21  N_fertilisation_dose_3  13 non-null     float64
#  22  N_fertilisation_date_1  218 non-null    object
#  23  N_fertilisation_date_2  92 non-null     object
#  24  N_fertilisation_date_3  13 non-null     object
#  25  N_fertilisation_type    276 non-null    object
#  26  N_fertiliser            208 non-null    object
#  27  irrigation_amount       771 non-null    float64
#  28  P_amount                915 non-null    int64
#  29  pest_control            915 non-null    object
# dtypes: float64(8), int64(2), object(20)
# memory usage: 214.6+ KB

# %%
data_management.head(2).T
# Out:
#                                                    0  \
# experiment_id           Angers_brainsurlauthion_2011
# management                                        M1
# crop_type                                         SC
# crop_season                                   winter
# species                               wheat_aestivum
# species_mix                           wheat_aestivum
# cultivar                                     cezanne
# cultivar_mix                                 cezanne
# density_level                                  250.0
# density_relative                                 1.0
# density_factor                                     1
# interrow                                        0.17
# mixing_pattern                                   NaN
# code_row                                         NaN
# mixture_design                                   NaN
# sowing_date                               2010-10-29
# harvest_date                              2011-07-06
# N_amount                                         140
# N_fertilisation_number                           1.0
# N_fertilisation_dose_1                         140.0
# N_fertilisation_dose_2                           NaN
# N_fertilisation_dose_3                           NaN
# N_fertilisation_date_1                           NaN
# N_fertilisation_date_2                           NaN
# N_fertilisation_date_3                           NaN
# N_fertilisation_type                             NaN
# N_fertiliser                                     NaN
# irrigation_amount                               60.0
# P_amount                                           0
# pest_control                                     yes
#
#                                                    1
# experiment_id           Angers_brainsurlauthion_2011
# management                                        M2
# crop_type                                         SC
# crop_season                                   winter
# species                                          pea
# species_mix                                      pea
# cultivar                                      aoph10
# cultivar_mix                                  aoph10
# density_level                                   80.0
# density_relative                                 1.0
# density_factor                                     1
# interrow                                        0.17
# mixing_pattern                                   NaN
# code_row                                         NaN
# mixture_design                                   NaN
# sowing_date                               2010-10-29
# harvest_date                              2011-06-21
# N_amount                                           0
# N_fertilisation_number                           NaN
# N_fertilisation_dose_1                           NaN
# N_fertilisation_dose_2                           NaN
# N_fertilisation_dose_3                           NaN
# N_fertilisation_date_1                           NaN
# N_fertilisation_date_2                           NaN
# N_fertilisation_date_3                           NaN
# N_fertilisation_type                             NaN
# N_fertiliser                                     NaN
# irrigation_amount                               60.0
# P_amount                                           0
# pest_control                                     yes

# %%
data_management[['harvest_date', 'sowing_date']] = data_management[
    ['harvest_date', 'sowing_date']
].apply(lambda col: pd.to_datetime(col).dt.normalize())

# %%
# Merge processed data_traits with data_management
merge_keys = [
    'experiment_id', 'management', 'crop_type', 'crop_season', 
    'species', 'species_mix',
    'sowing_date', 'harvest_date'
]

traits_management = pd.merge(
    merged_df,
    data_management,
    on=merge_keys,  # Ensure these columns exist in both DataFrames
    how='left',
    suffixes=('', '_management')
)

# %%
traits_management.head(2).T
# Out:
#                                                0                    1
# experiment_id                  Angers_fnams_2002    Angers_fnams_2002
# management                                    M3                   M3
# crop_type                                     IC                   IC
# crop_season                               spring               spring
# plant_family                              cereal               legume
# species                                   barley                  pea
# species_mix                           barley_pea           barley_pea
# sowing_date                  2002-03-28 00:00:00  2002-03-28 00:00:00
# harvest_date                 2002-07-08 00:00:00  2002-07-08 00:00:00
# biomass_seed                                 1.3                  3.4
# plant_density                               33.0                 54.0
# density_relative                            0.33                  1.0
# density_factor                            0.33_1               0.33_1
# N_amount                                       0                    0
# cultivar                                scarlett              baccara
# cultivar_mix                    scarlett_baccara     scarlett_baccara
# cultivar_management                     scarlett              baccara
# cultivar_mix_management         scarlett_baccara     scarlett_baccara
# density_level                               40.0                 80.0
# density_relative_management                 0.33                  1.0
# density_factor_management                 0.33_1               0.33_1
# interrow                                    0.15                 0.15
# mixing_pattern                     alternate_row        alternate_row
# code_row                                     1_1                  1_1
# mixture_design                          additive             additive
# N_amount_management                            0                    0
# N_fertilisation_number                       NaN                  NaN
# N_fertilisation_dose_1                       NaN                  NaN
# N_fertilisation_dose_2                       NaN                  NaN
# N_fertilisation_dose_3                       NaN                  NaN
# N_fertilisation_date_1                       NaN                  NaN
# N_fertilisation_date_2                       NaN                  NaN
# N_fertilisation_date_3                       NaN                  NaN
# N_fertilisation_type                         NaN                  NaN
# N_fertiliser                                 NaN                  NaN
# irrigation_amount                          105.0                105.0
# P_amount                                       0                    0
# pest_control                                 yes                  yes

# %%
data_trials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            37 non-null     object
#  1   site               37 non-null     object
#  2   plot_name          37 non-null     object
#  3   year               37 non-null     int64
#  4   experiment_id      37 non-null     object
#  5   plot_lat           37 non-null     float64
#  6   plot_long          37 non-null     float64
#  7   soil_awc           8 non-null      float64
#  8   soil_clay          34 non-null     float64
#  9   soil_sand          34 non-null     float64
#  10  soil_silt          34 non-null     float64
#  11  soil_pH            30 non-null     float64
#  12  previous_crop      24 non-null     object
#  13  nitrogen_residual  18 non-null     float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 4.2+ KB

# %%
data_trials.head(2)
# Out:
#   country    site         plot_name  year                 experiment_id  \
# 0  France  Angers  brainsurlauthion  2011  Angers_brainsurlauthion_2011
# 1  France  Angers             fnams  2002             Angers_fnams_2002
#
#     plot_lat  plot_long  soil_awc  soil_clay  soil_sand  soil_silt  soil_pH  \
# 0  47.433333  -0.433333       NaN       0.51       0.23       0.26      NaN
# 1  47.450000  -0.400000      70.0        NaN        NaN        NaN      NaN
#
#   previous_crop  nitrogen_residual
# 0           NaN                NaN
# 1       mustard               22.0

# %%
merge_keys = ['experiment_id']

traits_management_trials = pd.merge(
    traits_management,
    data_trials,
    on=merge_keys,
    how='left',
    suffixes=('', '_trials')
)

# %%
traits_management_trials.columns
# Out:
# Index(['experiment_id', 'management', 'crop_type', 'crop_season',
#        'plant_family', 'species', 'species_mix', 'sowing_date', 'harvest_date',
#        'biomass_seed', 'plant_density', 'density_relative', 'density_factor',
#        'N_amount', 'cultivar', 'cultivar_mix', 'cultivar_management',
#        'cultivar_mix_management', 'density_level',
#        'density_relative_management', 'density_factor_management', 'interrow',
#        'mixing_pattern', 'code_row', 'mixture_design', 'N_amount_management',
#        'N_fertilisation_number', 'N_fertilisation_dose_1',
#        'N_fertilisation_dose_2', 'N_fertilisation_dose_3',
#        'N_fertilisation_date_1', 'N_fertilisation_date_2',
#        'N_fertilisation_date_3', 'N_fertilisation_type', 'N_fertiliser',
#        'irrigation_amount', 'P_amount', 'pest_control', 'country', 'site',
#        'plot_name', 'year', 'plot_lat', 'plot_long', 'soil_awc', 'soil_clay',
#        'soil_sand', 'soil_silt', 'soil_pH', 'previous_crop',
#        'nitrogen_residual'],
#       dtype='object')

# %%
data_climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27024 entries, 0 to 27023
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   experiment_id      27024 non-null  object
#  1   date               27024 non-null  object
#  2   T2M                27024 non-null  float64
#  3   T2M_MIN            27024 non-null  float64
#  4   T2M_MAX            27024 non-null  float64
#  5   PRECTOTCORR        27024 non-null  float64
#  6   ALLSKY_SFC_SW_DWN  27024 non-null  float64
#  7   RH2M               27024 non-null  float64
#  8   PET                27024 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 1.9+ MB

# %%
# Example: Growing season aggregation
climate_agg = data_climate.groupby('experiment_id').agg({
    'T2M': ['mean', 'max'],                          # Mean and peak temperatures
    'T2M_MAX': lambda x: (x > 30).sum(),             # Heat stress days
    'PRECTOTCORR': 'sum',                            # Total precipitation
    'ALLSKY_SFC_SW_DWN': 'sum',                      # Total solar radiation
    'PET': 'mean',                                   # Average water demand
    'RH2M': lambda x: (x > 80).sum()                 # High humidity days
}).reset_index()

# Rename columns for clarity
climate_agg.columns = [
    'experiment_id',
    'mean_temperature', 'max_temperature',
    'heat_stress_days', 'total_precipitation',
    'total_solar_radiation', 'mean_PET',
    'high_humidity_days'
]

# %%
climate_agg
# Out:
#                                experiment_id  mean_temperature  \
# 0               Angers_brainsurlauthion_2011         11.361178
# 1                          Angers_fnams_2002         11.349959
# 2                          Angers_fnams_2003         11.678068
# 3                      Angers_jailliere_2007         11.828959
# 4                      Angers_jailliere_2008         11.295335
# 5                       Angers_thorigne_2003         11.678068
# 6                       Angers_thorigne_2004         11.533639
# 7                       Angers_thorigne_2006         11.940425
# 8                       Angers_thorigne_2007         11.820562
# 9                       Angers_thorigne_2008         11.276908
# 10                      Angers_thorigne_2009         11.166854
# 11                         Auzeville_PP_2011         13.259123
# 12                        Auzeville_SGs_2007         13.605575
# 13                         Auzeville_TE_2006         13.511466
# 14                         Auzeville_TO_2013         12.995581
# 15                         Auzeville_TO_2016         13.920109
# 16                         Auzeville_ZN_2012         13.804761
# 17                    Auzeville_cochard_2010         12.886452
# 18                Auzeville_marinette_1_2015         14.021137
# 19                Auzeville_marinette_2_2015         14.021137
# 20                         Auzeville_pk_2011         13.259123
# 21                       Copenhagen_hbg_2001          8.708878
# 22                       Copenhagen_hbg_2002          8.639877
# 23                       Copenhagen_hbg_2003          8.734178
# 24                        Grignon_inrae_2007         11.195945
# 25                        Grignon_inrae_2008         10.696361
# 26                        Grignon_inrae_2009         10.603324
# 27                        Grignon_inrae_2010         10.232466
# 28                        Grignon_inrae_2017         11.271122
# 29                         Jyndevad_jyn_2001          8.668906
# 30                         Jyndevad_jyn_2002          8.611959
# 31                         Jyndevad_jyn_2003          8.744000
# 32                        Kassel_kassel_2004          8.224720
# 33                      Reading_reading_2003         10.027479
# 34  Sanmarcoargentano_sanmarcoargentano_2003         15.008219
# 35  Sanmarcoargentano_sanmarcoargentano_2004         14.823707
# 36                    Taastrup_taastrup_2003          8.734178
#
#     max_temperature  heat_stress_days  total_precipitation  \
# 0             26.01                 6              1221.79
# 1             24.19                 0              1643.07
# 2             28.21                15              1451.31
# 3             27.40                11              1636.91
# 4             21.65                 0              1592.27
# 5             28.21                15              1451.31
# 6             28.21                20              1255.58
# 7             27.90                34              1326.96
# 8             27.90                18              1532.13
# 9             22.37                 1              1503.56
# 10            25.04                 4              1454.85
# 11            29.99                74              1389.46
# 12            30.60                69              1395.83
# 13            29.94                91              1401.49
# 14            30.33                81              1674.71
# 15            29.30                83              1524.77
# 16            30.33                93              1301.25
# 17            30.03                75              1538.94
# 18            29.30                63              1547.32
# 19            29.30                63              1547.32
# 20            29.99                74              1389.46
# 21            22.10                 0              1447.72
# 22            21.40                 0              1578.93
# 23            22.40                 0              1440.75
# 24            28.80                24              1377.21
# 25            23.53                 6              1378.44
# 26            26.88                18              1292.01
# 27            26.88                21              1272.91
# 28            28.69                22              1311.15
# 29            22.77                 0              1641.86
# 30            21.75                 0              1791.72
# 31            22.11                 0              1590.93
# 32            27.57                15              1454.77
# 33            25.02                 3              1488.12
# 34            29.68               105              1699.72
# 35            29.68               105              2123.88
# 36            22.40                 0              1440.75
#
#     total_solar_radiation  mean_PET  high_humidity_days
# 0                 9468.26  2.301465                 379
# 1                 8682.13  1.971932                 548
# 2                 9007.49  2.153154                 462
# 3                 9026.10  2.145767                 500
# 4                 9015.77  1.980146                 540
# 5                 9007.49  2.150353                 462
# 6                 9268.02  2.254875                 416
# 7                 9298.84  2.390584                 395
# 8                 9026.10  2.193891                 463
# 9                 9015.77  2.034235                 493
# 10                9318.41  2.135285                 450
# 11               10314.86  2.770909                 289
# 12               10201.90  2.783514                 304
# 13               10384.93  2.854115                 289
# 14               10126.02  2.679120                 338
# 15               10345.18  2.771931                 293
# 16               10380.84  2.893622                 273
# 17               10190.42  2.688160                 336
# 18               10355.98  2.757220                 281
# 19               10355.98  2.757220                 281
# 20               10314.86  2.770832                 289
# 21                7551.07  1.488281                 587
# 22                7478.51  1.529254                 599
# 23                7729.00  1.592499                 579
# 24                8581.63  2.145033                 454
# 25                8599.88  2.022430                 463
# 26                8853.12  2.153166                 420
# 27                9058.69  2.240718                 382
# 28                8763.59  2.179069                 429
# 29                6893.25  1.396813                 630
# 30                7156.62  1.429458                 649
# 31                7518.01  1.516087                 624
# 32                7745.33  1.849888                 465
# 33                7685.16  1.715106                 537
# 34               11221.02  2.865133                 319
# 35               11463.44  2.841437                 336
# 36                7729.00  1.592443                 579

# %%
merge_keys = ['experiment_id']

final_df = pd.merge(
    traits_management_trials,
    climate_agg,
    on=['experiment_id'],
    how='left',
    suffixes=('', '_climate')
)

# %%
final_df.columns
# Out:
# Index(['experiment_id', 'management', 'crop_type', 'crop_season',
#        'plant_family', 'species', 'species_mix', 'sowing_date', 'harvest_date',
#        'biomass_seed', 'plant_density', 'density_relative', 'density_factor',
#        'N_amount', 'cultivar', 'cultivar_mix', 'cultivar_management',
#        'cultivar_mix_management', 'density_level',
#        'density_relative_management', 'density_factor_management', 'interrow',
#        'mixing_pattern', 'code_row', 'mixture_design', 'N_amount_management',
#        'N_fertilisation_number', 'N_fertilisation_dose_1',
#        'N_fertilisation_dose_2', 'N_fertilisation_dose_3',
#        'N_fertilisation_date_1', 'N_fertilisation_date_2',
#        'N_fertilisation_date_3', 'N_fertilisation_type', 'N_fertiliser',
#        'irrigation_amount', 'P_amount', 'pest_control', 'country', 'site',
#        'plot_name', 'year', 'plot_lat', 'plot_long', 'soil_awc', 'soil_clay',
#        'soil_sand', 'soil_silt', 'soil_pH', 'previous_crop',
#        'nitrogen_residual', 'mean_temperature', 'max_temperature',
#        'heat_stress_days', 'total_precipitation', 'total_solar_radiation',
#        'mean_PET', 'high_humidity_days'],
#       dtype='object')

# %%
final_df
# Out:
#                                 experiment_id management crop_type  \
# 0                           Angers_fnams_2002         M3        IC
# 1                           Angers_fnams_2002         M3        IC
# 2                           Angers_fnams_2003         M5        IC
# 3                           Angers_fnams_2003         M5        IC
# 4                           Angers_fnams_2003         M6        IC
# ..                                        ...        ...       ...
# 627  Sanmarcoargentano_sanmarcoargentano_2004         M3        IC
# 628                    Taastrup_taastrup_2003         M3        IC
# 629                    Taastrup_taastrup_2003         M3        IC
# 630                    Taastrup_taastrup_2003         M4        IC
# 631                    Taastrup_taastrup_2003         M4        IC
#
#     crop_season plant_family species species_mix sowing_date harvest_date  \
# 0        spring       cereal  barley  barley_pea  2002-03-28   2002-07-08
# 1        spring       legume     pea  barley_pea  2002-03-28   2002-07-08
# 2        spring       cereal  barley  barley_pea  2003-03-12   2003-07-08
# 3        spring       legume     pea  barley_pea  2003-03-12   2003-07-08
# 4        spring       cereal  barley  barley_pea  2003-03-12   2003-07-08
# ..          ...          ...     ...         ...         ...          ...
# 627      spring       legume     pea  barley_pea  2004-03-15   2004-06-25
# 628      spring       cereal  barley  barley_pea  2003-04-04   2003-07-26
# 629      spring       legume     pea  barley_pea  2003-04-04   2003-07-26
# 630      spring       cereal  barley  barley_pea  2003-04-04   2003-07-26
# 631      spring       legume     pea  barley_pea  2003-04-04   2003-07-26
#
#      biomass_seed  ...  soil_pH  previous_crop nitrogen_residual  \
# 0        1.300000  ...      NaN        mustard              22.0
# 1        3.400000  ...      NaN        mustard              22.0
# 2        1.968870  ...      NaN         barley              71.0
# 3        4.321120  ...      NaN         barley              71.0
# 4        4.490746  ...      NaN         barley              71.0
# ..            ...  ...      ...            ...               ...
# 627      2.122396  ...      7.7    durum_wheat               NaN
# 628      1.929750  ...      6.6   winter_wheat               NaN
# 629      1.418750  ...      6.6   winter_wheat               NaN
# 630      1.627250  ...      6.6   winter_wheat               NaN
# 631      1.792250  ...      6.6   winter_wheat               NaN
#
#      mean_temperature max_temperature heat_stress_days total_precipitation  \
# 0           11.349959           24.19                0             1643.07
# 1           11.349959           24.19                0             1643.07
# 2           11.678068           28.21               15             1451.31
# 3           11.678068           28.21               15             1451.31
# 4           11.678068           28.21               15             1451.31
# ..                ...             ...              ...                 ...
# 627         14.823707           29.68              105             2123.88
# 628          8.734178           22.40                0             1440.75
# 629          8.734178           22.40                0             1440.75
# 630          8.734178           22.40                0             1440.75
# 631          8.734178           22.40                0             1440.75
#
#     total_solar_radiation  mean_PET  high_humidity_days
# 0                 8682.13  1.971932                 548
# 1                 8682.13  1.971932                 548
# 2                 9007.49  2.153154                 462
# 3                 9007.49  2.153154                 462
# 4                 9007.49  2.153154                 462
# ..                    ...       ...                 ...
# 627              11463.44  2.841437                 336
# 628               7729.00  1.592443                 579
# 629               7729.00  1.592443                 579
# 630               7729.00  1.592443                 579
# 631               7729.00  1.592443                 579
#
# [632 rows x 58 columns]

# %%
final_df.to_csv('merged_df')
